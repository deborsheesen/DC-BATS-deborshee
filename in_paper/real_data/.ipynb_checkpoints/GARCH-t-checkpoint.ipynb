# %%
# Calling libraries:
from __future__ import division
# %matplotlib inline
import numpy as np, time, matplotlib.pyplot as plt, numpy.random as npr, pystan as ps, pickle, pandas
from pylab import plot, show, legend
from time import time
from scipy.stats import *
from tqdm import trange

# %%
sm = ps.StanModel(file="garch_t.stan")
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_c2d2b11f53ac18648f7d8b74054e190a NOW.

# %%
dat = pandas.read_csv("la_pm_positive.csv").values
Y = dat[:,1]
T = len(Y)

# %%
p = 1
q = 1
r = np.maximum(p,q)
nu = 4

# %% [markdown]
# ### Divide-and-conquer:

# %%
K = 10
tstarts = np.arange(K).astype(int)
tends = 1 + tstarts
tstarts *= int(T/K)
tends *= int(T/K)

# %%
n_chains = 10
for k in range(K) :
    start = time()
    tstart, tend = tstarts[k], tends[k]
    data = dict(T=tend-tstart, p=p, q=q, r=r, nu=nu, y=Y[tstart:tend], power=K)
    fit = sm.sampling(data=data, thin=1, n_jobs=min(10,n_chains), chains=n_chains, init="random", iter=1_000)
    file = open("/xtmp/DC-BATS_data/real_data/garch_t_chunk"+str(k+1)+"_mcmc.pkl", "wb")
    pickle.dump(fit.extract(), file)
    file.close()
    mle = sm.optimizing(data=data)
    file = open("/xtmp/DC-BATS_data/real_data/garch_t_chunk"+str(k+1)+"_mle.pkl", "wb")
    pickle.dump(fit.extract(), file)
    file.close()
    print(round((time()-start)/60,2), "minutes to run")
# Out:
# 0.19 minutes to run
# 0.21 minutes to run
# 0.24 minutes to run
# WARNING:pystan:2 of 5000 iterations ended with a divergence (0.04 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# 0.22 minutes to run
# 0.23 minutes to run
# 0.22 minutes to run
# 0.19 minutes to run
# WARNING:pystan:1 of 5000 iterations ended with a divergence (0.02 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# 0.23 minutes to run
# 0.19 minutes to run
# 0.22 minutes to run

# %%
data = dict(T=T, p=p, q=q, r=r, nu=nu, y=Y, power=1)
start = time()
fit = sm.sampling(data=data, thin=1, n_jobs=min(10,n_chains), chains=n_chains, init="random", iter=n_iter)
print(round((time()-start)/60,2), "minutes to run")
trace = fit.extract()
# Out:
# 1.85 minutes to run

# %%
mle = sm.optimizing(data=data)

# %%
names = ['omega', 'beta', 'alpha']
plt.rcParams['figure.figsize'] = (15, 3)
for (i,name) in enumerate(names) :
    plt.subplot(1,len(names),i+1)
    plt.plot(trace[name])
    plt.grid(True)
    plt.xlabel("Time")
    plt.title(name, fontsize=14)
    print(np.var(trace[name]))
# Out:
# 0.028045333705894394
# 0.00044345090727932867
# 0.0006647826863800054

# %%
data = dict(T=T, p=p, q=q, r=r, nu=nu, y=Y, power=10)
start = time()
fit = sm.sampling(data=data, thin=1, n_jobs=min(10,n_chains), chains=n_chains, init="random", iter=n_iter)
print(round((time()-start)/60,2), "minutes to run")
trace = fit.extract()
# Out:
# 0.86 minutes to run

# %%
names = ['omega', 'beta', 'alpha']
plt.rcParams['figure.figsize'] = (15, 3)
for (i,name) in enumerate(names) :
    plt.subplot(1,len(names),i+1)
    plt.plot(trace[name])
    plt.grid(True)
    plt.xlabel("Time")
    plt.title(name, fontsize=14)
    print(np.var(trace[name]))
# Out:
# 0.00284126156589806
# 3.129441598939925e-05
# 5.864990048463542e-05

# %%
np.asarray([0.02123,0.00035,0.00066])/np.asarray([0.00281,3.23607e-05,5.88001e-05])
# Out:
# array([ 7.55516014, 10.81558804, 11.22447071])
