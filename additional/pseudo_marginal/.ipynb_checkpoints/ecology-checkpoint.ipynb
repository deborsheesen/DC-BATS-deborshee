# %% [markdown]
# ### Model:
#
# * $I$ species observed at $J$ locations over time.
#
# * $Y_{tij} = 1$ if species $i$ is observed at location $j$ at time $t$.

# %%
# Calling libraries:
from __future__ import division
# %matplotlib inline
import numpy as np, time, matplotlib.pyplot as plt, math, pandas, numpy.random as npr, multiprocessing as mp
from pylab import plot, show, legend
from time import time
from scipy.stats import *
from tqdm import trange
from ecology_functions import *

# %%
T = 100
n_locations = 3  # number of locations
n_species = 3 # number of species
n_factors = 2  # number of latent factors

# %%
lmbda = npr.randn(n_species,n_factors)
alpha = 0
c = 0
phi = 0.1
logsigmasq = 0
x_0 = np.zeros((n_locations,n_factors))

theta = [alpha, lmbda, c, phi, logsigmasq]

# %%
Y, X = simulate_data(x_0, T, n_species, theta)

# %%
n_particles = 1_000
logNC = bootstrap_PF(npr.randn(n_locations,n_factors), n_particles, theta, Y)
print(logNC)
# Out:
# 12252.859423086982

# %% [raw]
# j = 1
# k = 0
# ci = np.percentile(particles[1:,j,k], axis=1, q=[2.5,97.5])
# plt.rcParams['figure.figsize'] = (16, 3.5)
# plt.plot(1+np.arange(T), X[1:,j,k], 'bo-', markersize=3, lw=0.5)
# plt.fill_between(1+np.arange(T), ci[0], ci[1], color='red', alpha=.3)
# plt.xlim(0,T+1)
# plt.grid(True)

# %%
n_particles = T
n_mcmc = 50_000
eps = 1e-3
scale = [5*eps, eps*np.ones(np.shape(lmbda)), 2*eps, eps, eps]
theta_0 = theta

# %%
theta_chain, scale = pMCMC(x_0, Y, theta_0, n_particles, n_mcmc, scale, power=1, adapt=False)
# Out:
# /home/postdoc/dsen/.local/lib/python3.6/site-packages/numpy/lib/function_base.py:792: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, order=order, subok=subok, copy=True)
#  46%|████▋     | 23162/50000 [05:31<06:18, 70.88it/s]/home/postdoc/dsen/Desktop/codes/DC-BATS/pseudo_marginal/ecology_functions.py:53: RuntimeWarning: overflow encountered in exp
#   logNC += np.log(np.sum(np.exp(log_weights)))
# /home/postdoc/dsen/Desktop/codes/DC-BATS/pseudo_marginal/ecology_functions.py:54: RuntimeWarning: overflow encountered in exp
#   weights, particles = adaptive_resample(np.exp(log_weights), particles)
# /home/postdoc/dsen/Desktop/codes/DC-BATS/pseudo_marginal/ecology_functions.py:35: RuntimeWarning: invalid value encountered in true_divide
#   weights /= np.sum(weights)
#  52%|█████▏    | 25875/50000 [06:10<05:37, 71.44it/s]/home/postdoc/dsen/Desktop/codes/DC-BATS/pseudo_marginal/ecology_functions.py:154: RuntimeWarning: invalid value encountered in double_scalars
#   log_accept_prob = power*(ll_proposed-lls[n]) + (log_prior_proposed-log_prior_current)
#  60%|██████    | 30171/50000 [07:12<04:43, 70.06it/s]/home/postdoc/dsen/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /home/postdoc/dsen/Desktop/codes/DC-BATS/pseudo_marginal/ecology_functions.py:36: RuntimeWarning: divide by zero encountered in double_scalars
#   ESS = 1/np.sum(weights**2)
# 100%|██████████| 50000/50000 [13:26<00:00, 61.96it/s]
# 3.53 % acceptance rate

# %%
plt.rcParams['figure.figsize'] = (18, 2.5)
for (i,j) in enumerate([0,2,3,4]) :
    plt.subplot(1,4,i+1)
    plt.plot(theta_chain[j])
    plt.grid(True)
plt.show()

plt.rcParams['figure.figsize'] = (12, 5)
for i in range(n_factors) :
    for j in range(n_locations) :
        k = i*n_locations + j + 1
        plt.subplot(n_factors,n_locations,k)
        plt.plot(theta_chain[1][:,j,i])
        plt.grid(True)
plt.show()
