# %% [markdown]
# ### Raising prior to the power $1/$(number of chunks).

# %%
# Calling libraries:
from __future__ import division
# %matplotlib inline
import numpy as np, time, matplotlib.pyplot as plt, math, pandas, numpy.random as npr, pystan as ps
from pylab import plot, show, legend
from time import time
from scipy.stats import *
from Ricker_functions import *

# %%
sm = ps.StanModel(file="ricker_cmc.stan")
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_3247a99bc4ed32bdcfb49a0a7dbbd899 NOW.

# %%
x_0 = 5.
T = 50_000
r, sigma, phi = np.exp(2.8), 0.5, 3
theta = np.asarray([r, sigma, phi])

X, y = simulate_data(x_0, T, theta)

# %% [markdown]
# ### Divide-and-conquer

# %%
n_chains = 10
m = 10
tstarts = np.arange(m).astype(int)
tends = 1 + tstarts
tstarts *= int(T/m)
tends *= int(T/m)

# %%
traces = [[]]*m
for i in range(m) :
    tstart, tend = tstarts[i], tends[i]
    data = dict(T=tend-tstart, y=y[tstart:tend], x_0=x_0, power=T/(tend-tstart))
    fit = sm.sampling(data=data, thin=1, n_jobs=min(10,n_chains), chains=n_chains, init="random", iter=1_000)
    traces[i] = fit.extract()
# Out:
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:4976 of 5000 iterations ended with a divergence (99.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:24 of 5000 iterations saturated the maximum tree depth of 10 (0.48 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 2: E-BFMI = 0.0359
# WARNING:pystan:Chain 3: E-BFMI = 0.0218
# WARNING:pystan:Chain 4: E-BFMI = 0.0109
# WARNING:pystan:Chain 5: E-BFMI = 0.0436
# WARNING:pystan:Chain 7: E-BFMI = 0.0337
# WARNING:pystan:Chain 8: E-BFMI = 0.0949
# WARNING:pystan:Chain 9: E-BFMI = 0.0204
# WARNING:pystan:Chain 10: E-BFMI = 0.024
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:4961 of 5000 iterations ended with a divergence (99.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:39 of 5000 iterations saturated the maximum tree depth of 10 (0.78 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0148
# WARNING:pystan:Chain 2: E-BFMI = 0.0218
# WARNING:pystan:Chain 3: E-BFMI = 0.0385
# WARNING:pystan:Chain 4: E-BFMI = 0.0333
# WARNING:pystan:Chain 5: E-BFMI = 0.0152
# WARNING:pystan:Chain 6: E-BFMI = 0.189
# WARNING:pystan:Chain 7: E-BFMI = 0.027
# WARNING:pystan:Chain 8: E-BFMI = 0.0204
# WARNING:pystan:Chain 9: E-BFMI = 0.0358
# WARNING:pystan:Chain 10: E-BFMI = 0.032
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:4978 of 5000 iterations ended with a divergence (99.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:22 of 5000 iterations saturated the maximum tree depth of 10 (0.44 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0218
# WARNING:pystan:Chain 2: E-BFMI = 0.0142
# WARNING:pystan:Chain 3: E-BFMI = 0.022
# WARNING:pystan:Chain 4: E-BFMI = 0.0204
# WARNING:pystan:Chain 5: E-BFMI = 0.0399
# WARNING:pystan:Chain 6: E-BFMI = 0.0426
# WARNING:pystan:Chain 7: E-BFMI = 0.162
# WARNING:pystan:Chain 8: E-BFMI = 0.0316
# WARNING:pystan:Chain 9: E-BFMI = 0.00954
# WARNING:pystan:Chain 10: E-BFMI = 0.0167
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:4893 of 5000 iterations ended with a divergence (97.9 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:107 of 5000 iterations saturated the maximum tree depth of 10 (2.14 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0985
# WARNING:pystan:Chain 2: E-BFMI = 0.0144
# WARNING:pystan:Chain 3: E-BFMI = 0.0335
# WARNING:pystan:Chain 5: E-BFMI = 0.113
# WARNING:pystan:Chain 7: E-BFMI = 0.0529
# WARNING:pystan:Chain 8: E-BFMI = 0.131
# WARNING:pystan:Chain 9: E-BFMI = 0.189
# WARNING:pystan:Chain 10: E-BFMI = 0.127
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:4932 of 5000 iterations ended with a divergence (98.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:68 of 5000 iterations saturated the maximum tree depth of 10 (1.36 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0212
# WARNING:pystan:Chain 2: E-BFMI = 0.0487
# WARNING:pystan:Chain 3: E-BFMI = 0.0122
# WARNING:pystan:Chain 4: E-BFMI = 0.0227
# WARNING:pystan:Chain 5: E-BFMI = 0.0125
# WARNING:pystan:Chain 6: E-BFMI = 0.0111
# WARNING:pystan:Chain 7: E-BFMI = 0.0846
# WARNING:pystan:Chain 8: E-BFMI = 0.0332
# WARNING:pystan:Chain 9: E-BFMI = 0.0249
# WARNING:pystan:Chain 10: E-BFMI = 0.0147
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:4889 of 5000 iterations ended with a divergence (97.8 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:111 of 5000 iterations saturated the maximum tree depth of 10 (2.22 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0204
# WARNING:pystan:Chain 2: E-BFMI = 0.188
# WARNING:pystan:Chain 3: E-BFMI = 0.041
# WARNING:pystan:Chain 5: E-BFMI = 0.0363
# WARNING:pystan:Chain 6: E-BFMI = 0.0233
# WARNING:pystan:Chain 7: E-BFMI = 0.0509
# WARNING:pystan:Chain 8: E-BFMI = 0.0311
# WARNING:pystan:Chain 9: E-BFMI = 0.0253
# WARNING:pystan:Chain 10: E-BFMI = 0.0374
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model

# %%
phi_ci = np.zeros(2)
logr_ci = np.zeros(2)
sigma_ci = np.zeros(2)
for i in range(int(m)) :
    phi_ci += np.percentile(traces[i]['phi'],q=[2.5,97.5])/m
    logr_ci += np.percentile(traces[i]['logr'],q=[2.5,97.5])/m
    sci = np.percentile(traces[i]['sigma'],q=[2.5,97.5])
    sigma_ci += np.percentile(traces[i]['sigma'],q=[2.5,97.5])/m

# %%
print("phi credible interval divide-and-conquer:", phi_ci)
# print("phi credible interval MCMC on full data :", np.percentile(trace['phi'],q=[2.5,97.5]))
print("               True phi                 :", phi)
# Out:
# phi credible interval divide-and-conquer: [7.44252732e-307 1.23763786e-306]
#                True phi                 : 3

# %%
print("log r credible interval divide-and-conquer:", logr_ci)
# print("log r credible interval MCMC on full data:", np.percentile(trace['logr'],q=[2.5,97.5]))
print("               True log r                 :", np.log(r))
# Out:
# log r credible interval divide-and-conquer: [-8.62856588 50.6364734 ]
#                True log r                 : 2.8

# %%
print("sigma credible interval divide-and-conquer:", sigma_ci)
# print("sigma credible interval MCMC on full data:", np.percentile(trace['sigma'],q=[2.5,97.5]))
print("               True sigma                 :", sigma)
# Out:
# sigma credible interval divide-and-conquer: [1.06646217e+307 1.79444966e+307]
#                True sigma                 : 0.5

# %%
i = 0
tstart, tend = tstarts[i], tends[i]
plt.rcParams['figure.figsize'] = (16, 3.5)
plt.plot(1+np.arange(tstart,tend), X[tstart:tend], 'bo-', markersize=3, lw=0.5)
# plt.fill_between(1+np.arange(t_start,t_end), np.percentile(particles[1:],axis=1,q=5), 
#                  np.percentile(particles[1:],axis=1,q=95), color='red', alpha=.3)
plt.grid(True)
plt.yscale('log')
plt.xlim(tstart,tend+1)
# Out:
# (0, 5001)
